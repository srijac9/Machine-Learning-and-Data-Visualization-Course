# %% [markdown]
# <a href="https://colab.research.google.com/github/srijac9/Machine-Learning-and-Data-Visualization-Course/blob/main/2023_11_27_SrijaChitturi_Project86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Activity 1: Read the Image file In this activity, you need to execute a code cell which will
# read the image file from the link given using the imread() function.

# %%
import matplotlib.pyplot as plt
from skimage import io

img = io.imread('https://s3-whjr-v2-prod-bucket.whjr.online/71d278a3-604d-4f24-a6a4-4e09f0ae11ca.png')
print(img)
# Out:
# [[[ 34  68  17]
#   [ 36  46   3]
#   [ 34  68  17]
#   ...
#   [ 53  67  17]
#   [ 36  46   3]
#   [ 53  67  17]]
#
#  [[ 36  46   3]
#   [ 34  68  17]
#   [ 36  46   3]
#   ...
#   [ 53  67  17]
#   [ 36  46   3]
#   [ 53  67  17]]
#
#  [[ 36  46   3]
#   [ 34  68  17]
#   [ 36  46   3]
#   ...
#   [ 36  46   3]
#   [ 36  46   3]
#   [ 53  67  17]]
#
#  ...
#
#  [[170 204  68]
#   [170 204  68]
#   [170 204  68]
#   ...
#   [137 153  45]
#   [119 153  51]
#   [119 153  51]]
#
#  [[170 204  68]
#   [170 204  68]
#   [170 204  68]
#   ...
#   [119 153  51]
#   [119 153  51]
#   [137 153  45]]
#
#  [[187 204  68]
#   [170 204  68]
#   [187 204  68]
#   ...
#   [137 153  45]
#   [119 153  51]
#   [121 136  51]]]

# %%
#type and shape of img

print(type(img))

print(img.shape) # the height of the image is 1213 and the width is 560
# Out:
# <class 'numpy.ndarray'>
# (1213, 560, 3)

# %% [markdown]
# Activity 2: Display the Image In this activity, you have to display the image using the
# matplotlib.pyplot.imshow() function using different parameters.

# %%
plt.imshow(img)

# %%
plt.imshow(img,cmap='gray', vmin = 0, vmax = 255) # there is no change, doesn't change to gray

# %%
# converting and displaying in 2d
plt.imshow(img[:,:,0])

# %%
#using gray scale
plt.imshow(img[:,:,0], cmap = 'gray')
